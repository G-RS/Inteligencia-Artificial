# %% [markdown]
# # Projeto de precificação do valor cobrado para entrega de esculturas
#
# ![](https://camo.githubusercontent.)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate, KFold
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Aula 1 - Trabalhando com os dados

# %%
url = 'https://raw.githubusercontent.com/Mirlaa/regressao-arvores/main/dados_curso/entregas.csv'

url_teste = 'https://raw.githubusercontent.com/Mirlaa/regressao-arvores/main/dados_curso/teste_entregas.csv'

# %%
dados = pd.read_csv(url)

dados.head()
# Out:
#                              id_cliente    nome_artista  reputacao_artista  \
# 0  e9dff114-bc2b-47e9-9f5c-669e32ad9bbe   Billy Jenkins               0.26
# 1  ba3b707f-b123-4eec-93f4-1fbebfe72b68     Jean Bryant               0.28
# 2  c4212086-3e22-489e-bc2e-0d5092ef0526    Laura Miller               0.07
# 3  fec1bee9-44cf-498f-a849-5e5e2cab062b  Robert Chaires               0.12
# 4  f9f2ed8c-7f56-4e69-a80e-cb01d0a711da    Rosalyn Krol               0.15
#
#    altura  largura         peso  material  preco_escultura  preco_base_envio  \
# 0  5.1816   1.8288  1872.427776     Latão          73027.5           85.4175
# 1  0.9144   0.9144    27.669112     Latão          35857.5           78.7500
# 2  2.4384   1.5240   107.501304    Argila          26040.0          111.1950
# 3  2.7432   2.4384  1407.042384  Alumínio          30502.5           85.6275
# 4  5.1816   1.8288   146.963808  Alumínio          16695.0           62.6850
#
#   internacional envio_expresso instalacao_incluida        transporte fragil  \
# 0           Sim            Sim                 Não             Aéreo    Não
# 1           Não            Não                 Não        Rodoviário    Não
# 2           Não            Não                 Não        Rodoviário    Sim
# 3           Não            Não                 Não  Não especificado    Não
# 4           Sim            Sim                 Sim             Aéreo    Não
#
#   pedido_extra_cliente localizacao_remota data_agendada data_entrega  \
# 0                  Sim                Não      07/06/19     03/06/19
# 1                  Sim                Não      06/03/21     05/03/21
# 2                  Sim                Sim      09/03/19     08/03/19
# 3                  Não                Sim      24/05/19     20/05/19
# 4                  Sim                Não      18/12/20     14/12/20
#
#        custo
# 0  1487.2725
# 1   839.7900
# 2   810.0225
# 3   846.0900
# 4   835.9575

# %% [markdown]
# Dicionário de dados:
#
# | Nome da Coluna       | Descrição                                                      |
# |----------------------|----------------------------------------------------------------|
# | id_cliente        | Representa o número de identificação único dos clientes        |
# | nome_artista      | Representa o nome do artista                                   |
# | reputacao_artista | Representa a reputação de um artista no mercado (quanto maior o valor da reputação, maior a reputação do artista no mercado) |
# | altura               | Representa a altura da escultura em metros                     |
# | largura              | Representa a largura da escultura em metros                     |
# | peso                 | Representa o peso da escultura em quilos                       |
# | material             | Representa o material do qual a escultura é feita              |
# | preco_escultura   | Representa o preço da escultura         |
# | preco_base_envio  | Representa o preço base para o envio de uma escultura          |
# | internacional        | Indica se o envio é internacional                              |
# | envio_expresso       | Indica se o envio foi no modo expresso (rápido)    |
# | instalacao_incluida  | Indica se a instalação estava incluída na compra da escultura  |
# | transporte           | Representa o modo de transporte do pedido                      |
# | fragil               | Indica se o pedido é frágil                                    |
# | pedido_extra_cliente | Representa se o cliente deixou detalhes a mais para entrega     |
# | data_agendada        | Representa a data de previsão de entrega        |
# | data_entrega      | Representa a data de entrega do pedido          |
# | custo                | Representa o custo do envio do pedido      |

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4462 entries, 0 to 4461
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_cliente            4462 non-null   object
#  1   nome_artista          4462 non-null   object
#  2   reputacao_artista     4462 non-null   float64
#  3   altura                4462 non-null   float64
#  4   largura               4462 non-null   float64
#  5   peso                  4462 non-null   float64
#  6   material              4462 non-null   object
#  7   preco_escultura       4462 non-null   float64
#  8   preco_base_envio      4462 non-null   float64
#  9   internacional         4462 non-null   object
#  10  envio_expresso        4462 non-null   object
#  11  instalacao_incluida   4462 non-null   object
#  12  transporte            4462 non-null   object
#  13  fragil                4462 non-null   object
#  14  pedido_extra_cliente  4462 non-null   object
#  15  localizacao_remota    4462 non-null   object
#  16  data_agendada         4462 non-null   object
#  17  data_entrega          4462 non-null   object
#  18  custo                 4462 non-null   float64
# dtypes: float64(7), object(12)
# memory usage: 662.5+ KB

# %% [markdown]
# **ENTENDENDO AS COLUNAS**
#
# **Dado numérico:**
# - `'reputacao_artista'`, `'altura'`, `'largura'`, `'peso'`, `'preco_escultura'`, `'preco_base_envio'`.
#
# **Categóricas:**
#
# - `'id_cliente'`, `'nome_artista'`, `'material'`, `'internacional'`, `'envio_expresso'`, `'instalacao_incluida'`, `'transporte'`, `'fragil'`, `'pedido_extra_cliente'`, `localizacao_remota`.
#
# **Datas:**
#
# - `'data_agendada'`, `'data_entrega'`.
#
# **Alvo:**
# - `'custo'`.

# %%
df = dados.copy()

# %%
df['data_agendada'] = pd.to_datetime(df['data_agendada'], format='%d/%m/%y')
df['data_entrega'] = pd.to_datetime(df['data_entrega'], format='%d/%m/%y')

# %%
df['diferenca_dias_entrega'] = (df['data_entrega'] - df['data_agendada']).dt.days

# %%
df['data_agendada_dias'] = df['data_agendada'].dt.day
df['data_agendada_mes'] = df['data_agendada'].dt.month
df['data_agendada_ano'] = df['data_agendada'].dt.year

# %%
df['data_entrega_dias'] = df['data_entrega'].dt.day
df['data_entrega_mes'] = df['data_entrega'].dt.month
df['data_entrega_ano'] = df['data_entrega'].dt.year

# %%
df.drop(columns=['data_agendada', 'data_entrega'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4462 entries, 0 to 4461
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_cliente              4462 non-null   object
#  1   nome_artista            4462 non-null   object
#  2   reputacao_artista       4462 non-null   float64
#  3   altura                  4462 non-null   float64
#  4   largura                 4462 non-null   float64
#  5   peso                    4462 non-null   float64
#  6   material                4462 non-null   object
#  7   preco_escultura         4462 non-null   float64
#  8   preco_base_envio        4462 non-null   float64
#  9   internacional           4462 non-null   object
#  10  envio_expresso          4462 non-null   object
#  11  instalacao_incluida     4462 non-null   object
#  12  transporte              4462 non-null   object
#  13  fragil                  4462 non-null   object
#  14  pedido_extra_cliente    4462 non-null   object
#  15  localizacao_remota      4462 non-null   object
#  16  custo                   4462 non-null   float64
#  17  diferenca_dias_entrega  4462 non-null   int64
#  18  data_agendada_dias      4462 non-null   int32
#  19  data_agendada_mes       4462 non-null   int32
#  20  data_agendada_ano       4462 non-null   int32
#  21  data_entrega_dias       4462 non-null   int32
#  22  data_entrega_mes        4462 non-null   int32
#  23  data_entrega_ano        4462 non-null   int32
# dtypes: float64(7), int32(6), int64(1), object(10)
# memory usage: 732.2+ KB

# %%
colunas_categoricas = ['id_cliente', 'nome_artista', 'material', 'internacional', 'envio_expresso', 'instalacao_incluida',
                       'transporte', 'fragil', 'pedido_extra_cliente','localizacao_remota']

for column in colunas_categoricas:
    unique_values = df[column].unique()
    print(f"Valores únicos na coluna '{column}' \n {len(unique_values)} valores:")
    print(unique_values)
    print('=='*45)
# Out:
# Valores únicos na coluna 'id_cliente'
#  4462 valores:
# ['e9dff114-bc2b-47e9-9f5c-669e32ad9bbe'
#  'ba3b707f-b123-4eec-93f4-1fbebfe72b68'
#  'c4212086-3e22-489e-bc2e-0d5092ef0526' ...
#  'e1004685-9047-4f34-9103-57d900716936'
#  'a380ff88-2c96-4d70-919a-af0bc8caeed7'
#  '26fea648-9cc1-4a2b-9458-0b2d35957803']
# ==========================================================================================
# Valores únicos na coluna 'nome_artista'
#  4441 valores:
# ['Billy Jenkins' 'Jean Bryant' 'Laura Miller' ... 'William Curry'
#  'Karen Bayles' 'Denise Worth']
# ==========================================================================================
# Valores únicos na coluna 'material'
#  8 valores:
# ['Latão' 'Argila' 'Alumínio' 'Madeira' 'Bronze' 'Pedra' 'Não especificado'
#  'Mármore']
# ==========================================================================================
# Valores únicos na coluna 'internacional'
#  2 valores:
# ['Sim' 'Não']
# ==========================================================================================
# Valores únicos na coluna 'envio_expresso'
#  2 valores:
# ['Sim' 'Não']
# ==========================================================================================
# Valores únicos na coluna 'instalacao_incluida'
#  2 valores:
# ['Não' 'Sim']
# ==========================================================================================
# Valores únicos na coluna 'transporte'
#  4 valores:
# ['Aéreo' 'Rodoviário' 'Não especificado' 'Aquaviário']
# ==========================================================================================
# Valores únicos na coluna 'fragil'
#  2 valores:
# ['Não' 'Sim']
# ==========================================================================================
# Valores únicos na coluna 'pedido_extra_cliente'
#  2 valores:
# ['Sim' 'Não']
# ==========================================================================================
# Valores únicos na coluna 'localizacao_remota'
#  2 valores:
# ['Não' 'Sim']
# ==========================================================================================

# %% [markdown]
# **ENTENDENDO AS COLUNAS TEXTUAIS**
#
# **Categóricas:**
#
# - *Valores binários*: `'internacional'`, `'envio_expresso'`, `'instalacao_incluida'`,  `'fragil'`, `'pedido_extra_cliente'`, `'localizacao_remota'`.
# - *Várias Categorias*:`'material'`, `'transporte'`
# - *Valores únicos*: `'id_cliente'`, `'nome_artista'`

# %%
categoricas = ['internacional', 'envio_expresso', 'instalacao_incluida', 'fragil',
               'pedido_extra_cliente','localizacao_remota', 'material', 'transporte']

df = pd.get_dummies(df, columns=categoricas, drop_first=True)

# %%
df.drop(columns=['id_cliente', 'nome_artista'], inplace=True)

# %%
df
# Out:
#       reputacao_artista  altura  largura         peso  preco_escultura  \
# 0               0.26000  5.1816   1.8288  1872.427776          73027.5
# 1               0.28000  0.9144   0.9144    27.669112          35857.5
# 2               0.07000  2.4384   1.5240   107.501304          26040.0
# 3               0.12000  2.7432   2.4384  1407.042384          30502.5
# 4               0.15000  5.1816   1.8288   146.963808          16695.0
# ...                 ...     ...      ...          ...              ...
# 4457            0.93000  6.0960   2.4384   294.381208          25462.5
# 4458            0.67000  3.9624   2.4384   215.456200          19162.5
# 4459            0.46185  3.9624   2.4384    69.853168          27982.5
# 4460            0.45000  6.0960   8.5344  4921.926792         161857.5
# 4461            0.68000  5.7912   2.4384   266.258504          36330.0
#
#       preco_base_envio      custo  diferenca_dias_entrega  data_agendada_dias  \
# 0              85.4175  1487.2725                      -4                   7
# 1              78.7500   839.7900                      -1                   6
# 2             111.1950   810.0225                      -1                   9
# 3              85.6275   846.0900                      -4                  24
# 4              62.6850   835.9575                      -4                  18
# ...                ...        ...                     ...                 ...
# 4457          130.0950  3923.9550                       4                  23
# 4458           67.8825  1546.7550                      -1                  28
# 4459           68.2500   916.4925                       0                  16
# 4460          355.4250  5653.4625                       2                  19
# 4461           54.4950  1861.3875                      -1                  10
#
#       data_agendada_mes  ...  material_Argila  material_Bronze  \
# 0                     6  ...            False            False
# 1                     3  ...            False            False
# 2                     3  ...             True            False
# 3                     5  ...            False            False
# 4                    12  ...            False            False
# ...                 ...  ...              ...              ...
# 4457                  3  ...            False            False
# 4458                 10  ...            False            False
# 4459                  3  ...            False            False
# 4460                  4  ...            False            False
# 4461                  4  ...             True            False
#
#       material_Latão  material_Madeira  material_Mármore  \
# 0               True             False             False
# 1               True             False             False
# 2              False             False             False
# 3              False             False             False
# 4              False             False             False
# ...              ...               ...               ...
# 4457           False             False             False
# 4458           False             False             False
# 4459           False              True             False
# 4460           False             False             False
# 4461           False             False             False
#
#       material_Não especificado  material_Pedra  transporte_Aéreo  \
# 0                         False           False              True
# 1                         False           False             False
# 2                         False           False             False
# 3                         False           False             False
# 4                         False           False              True
# ...                         ...             ...               ...
# 4457                      False           False             False
# 4458                      False           False             False
# 4459                      False           False              True
# 4460                      False           False             False
# 4461                      False           False             False
#
#       transporte_Não especificado  transporte_Rodoviário
# 0                           False                  False
# 1                           False                   True
# 2                           False                   True
# 3                            True                  False
# 4                           False                  False
# ...                           ...                    ...
# 4457                        False                  False
# 4458                        False                   True
# 4459                        False                  False
# 4460                        False                   True
# 4461                         True                  False
#
# [4462 rows x 30 columns]

# %% [markdown]
# ## Visualizando dados

# %%
plt.figure(figsize=(10, 6))
plt.title("Distribuição do custo da entrega", fontsize=18)
plt.ylabel("Frequência", fontsize=14, labelpad=10)
plt.xlabel("Custo", fontsize=14, labelpad=10)
plt.tick_params(labelsize=12)

sns.histplot(df['custo'])
sns.despine();

# %%
plt.figure(figsize=(10, 6))
plt.title("Relação entre peso das esculturas e o custo", fontsize=18, pad=15)
plt.ylabel("Custo", fontsize=14, labelpad=10)
plt.xlabel("Peso", fontsize=14, labelpad=10)
plt.tick_params(labelsize=12)

sns.scatterplot(df, x='peso', y='custo');

# %%
plt.figure(figsize=(10, 6))
plt.title("Relação entre reputação do artista e o custo", fontsize=18, pad=15)
plt.ylabel("Custo", fontsize=14, labelpad=10)
plt.xlabel("Reputação do artista", fontsize=14, labelpad=10)
plt.tick_params(labelsize=12)

sns.scatterplot(df, x='reputacao_artista', y='custo');

# %% [markdown]
# # Aula 2 - Construindo Árvore de Regressão

# %%
X = df.drop(columns=['custo'])
y = df['custo']

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.2, random_state=45)

# %%
len(X_teste), len(X_treino)
# Out:
# (893, 3569)

# %%
dtr = DecisionTreeRegressor(random_state=45)
dtr.fit(X_treino, y_treino)
# Out:
# DecisionTreeRegressor(random_state=45)

# %%
print('Métricas conjunto de treino:')
print('R²:', r2_score(y_treino, dtr.predict(X_treino)))
print('MAE:', mean_absolute_error(y_treino, dtr.predict(X_treino)))
print('RMSE:', root_mean_squared_error(y_treino, dtr.predict(X_treino)))

print('\n\nMétricas conjunto de teste:')
print('R²:', r2_score(y_teste, dtr.predict(X_teste)))
print('MAE:', mean_absolute_error(y_teste, dtr.predict(X_teste)))
print('RMSE:', root_mean_squared_error(y_teste, dtr.predict(X_teste)))
# Out:
# Métricas conjunto de treino:
# R²: 1.0
# MAE: 0.0
# RMSE: 0.0
#
#
# Métricas conjunto de teste:
# R²: 0.660591437323694
# MAE: 694.1638773796193
# RMSE: 1544.651772523526

# %%
print(f"Número de nós: {dtr.tree_.node_count}")
print(f"Número de folhas: {dtr.tree_.n_leaves}")
print(f"Profundidade máxima: {dtr.tree_.max_depth}")
# Out:
# Número de nós: 7135
# Número de folhas: 3568
# Profundidade máxima: 30

# %%
dtr.feature_names_in_
# Out:
# array(['reputacao_artista', 'altura', 'largura', 'peso',
#        'preco_escultura', 'preco_base_envio', 'diferenca_dias_entrega',
#        'data_agendada_dias', 'data_agendada_mes', 'data_agendada_ano',
#        'data_entrega_dias', 'data_entrega_mes', 'data_entrega_ano',
#        'internacional_Sim', 'envio_expresso_Sim',
#        'instalacao_incluida_Sim', 'fragil_Sim',
#        'pedido_extra_cliente_Sim', 'localizacao_remota_Sim',
#        'material_Argila', 'material_Bronze', 'material_Latão',
#        'material_Madeira', 'material_Mármore',
#        'material_Não especificado', 'material_Pedra', 'transporte_Aéreo',
#        'transporte_Não especificado', 'transporte_Rodoviário'],
#       dtype=object)

# %%
dtr.feature_importances_
# Out:
# array([2.95578488e-01, 4.29089881e-02, 3.78042354e-02, 2.21994392e-02,
#        3.84947343e-01, 1.49395147e-01, 1.22586707e-02, 1.11972117e-02,
#        2.86561159e-03, 1.99295839e-03, 1.14020224e-02, 3.54964474e-03,
#        1.57834550e-03, 6.77238263e-04, 5.94807112e-03, 2.79459433e-03,
#        4.12356992e-03, 9.82178117e-04, 9.73419750e-04, 6.98369997e-04,
#        2.13022242e-04, 7.89364354e-04, 1.61255529e-04, 1.65835374e-04,
#        7.69720325e-04, 1.19398420e-05, 2.27767179e-03, 1.43086476e-03,
#        3.04778449e-04])

# %%
features_importancias = pd.DataFrame({'Feature': dtr.feature_names_in_,
                                      'Importância': dtr.feature_importances_}).sort_values(by='Importância', ascending=True)

plt.figure(figsize=(10, 6))
bars = plt.barh(features_importancias['Feature'], features_importancias['Importância'])
plt.xlabel('Importância Relativa')
plt.title('Importância das Características')
plt.show()

# %% [markdown]
# ## Identificando características da árvore

# %%
dtr.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': 45,
#  'splitter': 'best'}

# %%
plt.figure(figsize=(20, 10))
plot_tree(dtr, filled=True)
plt.title("Decision Tree sobreajustada aos dados de treino", fontsize=20)
plt.show()

# %% [markdown]
# # Aula 3 - Evitando o overfitting com a otimização

# %% [markdown]
# ![](https://camo.githubusercontent.com/43326da2d4c18114397fc7aa1b06b00e9c601d49638924dcc63a6f9072f5c847/68747470733a2f2f6769746875622e636f6d2f4d69726c61612f72656772657373616f2d6172766f7265732f626c6f622f6d61696e2f696d6167656e732d70726f6a65746f2f696d6167656d2d2d322e706e673f7261773d74727565)

# %%
params_grid = {
   'max_depth': [6, 8, 10, 15],
   'min_samples_split': [2, 5, 10],
   'min_samples_leaf': [5, 10, 15],
   'max_leaf_nodes': [None, 100, 500]
}

# %%
grid_search_dtr = GridSearchCV(dtr,
                           param_grid=params_grid,
                           scoring='neg_mean_squared_error',
                          cv=5,
                          n_jobs=-1)

grid_search_dtr.fit(X_treino, y_treino)

dtr_otimizado = grid_search_dtr.best_estimator_

print("Melhores parâmetros: ", grid_search_dtr.best_params_)
# Out:
# Melhores parâmetros:  {'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}

# %%
print('Métricas conjunto de treino:')
print('R²:', r2_score(y_treino, dtr_otimizado.predict(X_treino)))
print('MAE:', mean_absolute_error(y_treino, dtr_otimizado.predict(X_treino)))
print('RMSE:', root_mean_squared_error(y_treino, dtr_otimizado.predict(X_treino)))

print('\n\nMétricas conjunto de teste:')
print('R²:', r2_score(y_teste, dtr_otimizado.predict(X_teste)))
print('MAE:', mean_absolute_error(y_teste, dtr_otimizado.predict(X_teste)))
print('RMSE:', root_mean_squared_error(y_teste, dtr_otimizado.predict(X_teste)))
# Out:
# Métricas conjunto de treino:
# R²: 0.8709496124958277
# MAE: 473.70848177515785
# RMSE: 980.4175958553703
#
#
# Métricas conjunto de teste:
# R²: 0.7539366877133971
# MAE: 586.9786990247475
# RMSE: 1315.2024908853869

# %% [markdown]
# **VAMOS COMPARAR**
#
# ![](https://github.com/Mirlaa/regressao-arvores/blob/main/imagens-projeto/imagem-3.png?raw=true)

# %%
cv_estrategia = KFold(n_splits=3, shuffle=True, random_state=45)

resultados = cross_validate(dtr_otimizado, X, y, scoring='neg_mean_squared_error',
                            cv=cv_estrategia, return_train_score=True)

# %%
treino_rmse = np.sqrt(-resultados['train_score'])
teste_rmse = np.sqrt(-resultados['test_score'])

print("Treino RMSE em cada fold:", treino_rmse)
print("Teste RMSE em cada fold:", teste_rmse)
print("\nMédia do RMSE no treino:", treino_rmse.mean())
print("Média do RMSE no teste:", teste_rmse.mean())
# Out:
# Treino RMSE em cada fold: [1061.33787095  985.34242721 1023.82861998]
# Teste RMSE em cada fold: [1359.22040707 1469.19123426 1424.79371964]
#
# Média do RMSE no treino: 1023.5029727125925
# Média do RMSE no teste: 1417.7351203213384

# %% [markdown]
# ### Analisando a estrutura do novo modelo

# %%
print(f"Número de nós: {dtr_otimizado.tree_.node_count}")
print(f"Número de folhas: {dtr_otimizado.tree_.n_leaves}")
print(f"Profundidade máxima: {dtr_otimizado.tree_.max_depth}")
# Out:
# Número de nós: 381
# Número de folhas: 191
# Profundidade máxima: 10

# %%
features_importancias = pd.DataFrame({'Feature': dtr_otimizado.feature_names_in_,
                                      'Importância': dtr_otimizado.feature_importances_}).sort_values(by='Importância', ascending=True)

plt.figure(figsize=(10, 6))
bars = plt.barh(features_importancias['Feature'], features_importancias['Importância'])
plt.xlabel('Importância Relativa')
plt.title('Importância das Características')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plot_tree(dtr_otimizado, filled=True)
plt.title("Decision Tree otimizada", fontsize=20)
plt.show()

# %% [markdown]
# # Aula 4 - Implementando uma Floresta Aleatória

# %%
rfr = RandomForestRegressor(n_estimators=100, random_state=45, oob_score=True)
rfr.fit(X_treino, y_treino)
# Out:
# RandomForestRegressor(oob_score=True, random_state=45)

# %%
print('Métricas conjunto de treino:')
print('R²:', r2_score(y_treino, rfr.predict(X_treino)))
print('MAE:', mean_absolute_error(y_treino, rfr.predict(X_treino)))
print('RMSE:', root_mean_squared_error(y_treino, rfr.predict(X_treino)))

print('\n\nMétricas conjunto de teste:')
print('R²:', r2_score(y_teste, rfr.predict(X_teste)))
print('MAE:', mean_absolute_error(y_teste, rfr.predict(X_teste)))
print('RMSE:', root_mean_squared_error(y_teste, rfr.predict(X_teste)))

print('\n\nPrevisão OOB:', rfr.oob_score_)
# Out:
# Métricas conjunto de treino:
# R²: 0.9772974668010325
# MAE: 183.67128603950695
# RMSE: 411.21467064130854
#
#
# Métricas conjunto de teste:
# R²: 0.8253561789085245
# MAE: 459.512885106383
# RMSE: 1108.015414498702
#
#
# Previsão OOB: 0.8283734967539083

# %% [markdown]
# **VAMOS COMPARAR**
#
# ![](https://camo.githubusercontent.com/cbf99e32fd557fedb0f6cd563f350bbf7fb27bb0f91e9054505f71bcbe572dbe/68747470733a2f2f6769746875622e636f6d2f4d69726c61612f72656772657373616f2d6172766f7265732f626c6f622f6d61696e2f696d6167656e732d70726f6a65746f2f696d6167656d2d342e706e673f7261773d74727565)

# %%
cv_estrategia = KFold(n_splits=3, shuffle=True, random_state=45)

resultados = cross_validate(rfr, X, y, scoring='neg_mean_squared_error',
                            cv=cv_estrategia, return_train_score=True)

treino_rmse = np.sqrt(-resultados['train_score'])
teste_rmse = np.sqrt(-resultados['test_score'])

print("Média do RMSE no treino:", treino_rmse.mean())
print("Média do RMSE no teste:", teste_rmse.mean())
# Out:
# Média do RMSE no treino: 426.80944484310663
# Média do RMSE no teste: 1148.5596272436603

# %% [markdown]
# ### Verificando a estrutura da Floresta Aleatória

# %%
features_importancias = pd.DataFrame({'Feature': rfr.feature_names_in_,
                                      'Importância': rfr.feature_importances_}).sort_values(by='Importância', ascending=True)

plt.figure(figsize=(10, 6))
bars = plt.barh(features_importancias['Feature'], features_importancias['Importância'])
plt.xlabel('Importância Relativa')
plt.title('Importância das Características')
plt.show()

# %%
rfr.estimators_
# Out:
# [DecisionTreeRegressor(max_features=1.0, random_state=2100288459),
#  DecisionTreeRegressor(max_features=1.0, random_state=1307974046),
#  DecisionTreeRegressor(max_features=1.0, random_state=212792963),
#  DecisionTreeRegressor(max_features=1.0, random_state=736499580),
#  DecisionTreeRegressor(max_features=1.0, random_state=1208806944),
#  DecisionTreeRegressor(max_features=1.0, random_state=1804481119),
#  DecisionTreeRegressor(max_features=1.0, random_state=331956157),
#  DecisionTreeRegressor(max_features=1.0, random_state=1963884245),
#  DecisionTreeRegressor(max_features=1.0, random_state=1908981923),
#  DecisionTreeRegressor(max_features=1.0, random_state=1780867652),
#  DecisionTreeRegressor(max_features=1.0, random_state=2030694777),
#  DecisionTreeRegressor(max_features=1.0, random_state=2065337976),
#  DecisionTreeRegressor(max_features=1.0, random_state=208400399),
#  DecisionTreeRegressor(max_features=1.0, random_state=943505985),
#  DecisionTreeRegressor(max_features=1.0, random_state=701473166),
#  DecisionTreeRegressor(max_features=1.0, random_state=1569240373),
#  DecisionTreeRegressor(max_features=1.0, random_state=498004537),
#  DecisionTreeRegressor(max_features=1.0, random_state=245833590),
#  DecisionTreeRegressor(max_features=1.0, random_state=547143112),
#  DecisionTreeRegressor(max_features=1.0, random_state=939244759),
#  DecisionTreeRegressor(max_features=1.0, random_state=1529790254),
#  DecisionTreeRegressor(max_features=1.0, random_state=1361033480),
#  DecisionTreeRegressor(max_features=1.0, random_state=644684981),
#  DecisionTreeRegressor(max_features=1.0, random_state=1828241292),
#  DecisionTreeRegressor(max_features=1.0, random_state=2107633570),
#  DecisionTreeRegressor(max_features=1.0, random_state=466107772),
#  DecisionTreeRegressor(max_features=1.0, random_state=2020141080),
#  DecisionTreeRegressor(max_features=1.0, random_state=1348000012),
#  DecisionTreeRegressor(max_features=1.0, random_state=508070929),
#  DecisionTreeRegressor(max_features=1.0, random_state=1371572710),
#  DecisionTreeRegressor(max_features=1.0, random_state=1214046404),
#  DecisionTreeRegressor(max_features=1.0, random_state=1033884782),
#  DecisionTreeRegressor(max_features=1.0, random_state=2044418686),
#  DecisionTreeRegressor(max_features=1.0, random_state=298486942),
#  DecisionTreeRegressor(max_features=1.0, random_state=743321400),
#  DecisionTreeRegressor(max_features=1.0, random_state=571056398),
#  DecisionTreeRegressor(max_features=1.0, random_state=1892065770),
#  DecisionTreeRegressor(max_features=1.0, random_state=22076452),
#  DecisionTreeRegressor(max_features=1.0, random_state=1244197663),
#  DecisionTreeRegressor(max_features=1.0, random_state=596996694),
#  DecisionTreeRegressor(max_features=1.0, random_state=41659812),
#  DecisionTreeRegressor(max_features=1.0, random_state=236760761),
#  DecisionTreeRegressor(max_features=1.0, random_state=483015869),
#  DecisionTreeRegressor(max_features=1.0, random_state=1814980815),
#  DecisionTreeRegressor(max_features=1.0, random_state=974763409),
#  DecisionTreeRegressor(max_features=1.0, random_state=791305734),
#  DecisionTreeRegressor(max_features=1.0, random_state=2055366508),
#  DecisionTreeRegressor(max_features=1.0, random_state=261376554),
#  DecisionTreeRegressor(max_features=1.0, random_state=1042638347),
#  DecisionTreeRegressor(max_features=1.0, random_state=1101635816),
#  DecisionTreeRegressor(max_features=1.0, random_state=1666372232),
#  DecisionTreeRegressor(max_features=1.0, random_state=72816689),
#  DecisionTreeRegressor(max_features=1.0, random_state=1369550925),
#  DecisionTreeRegressor(max_features=1.0, random_state=2007456635),
#  DecisionTreeRegressor(max_features=1.0, random_state=320150219),
#  DecisionTreeRegressor(max_features=1.0, random_state=1407542013),
#  DecisionTreeRegressor(max_features=1.0, random_state=1817413439),
#  DecisionTreeRegressor(max_features=1.0, random_state=998756394),
#  DecisionTreeRegressor(max_features=1.0, random_state=965921334),
#  DecisionTreeRegressor(max_features=1.0, random_state=701845392),
#  DecisionTreeRegressor(max_features=1.0, random_state=886358772),
#  DecisionTreeRegressor(max_features=1.0, random_state=1237260793),
#  DecisionTreeRegressor(max_features=1.0, random_state=474875032),
#  DecisionTreeRegressor(max_features=1.0, random_state=1732111727),
#  DecisionTreeRegressor(max_features=1.0, random_state=433809392),
#  DecisionTreeRegressor(max_features=1.0, random_state=2052622569),
#  DecisionTreeRegressor(max_features=1.0, random_state=1747160671),
#  DecisionTreeRegressor(max_features=1.0, random_state=985971007),
#  DecisionTreeRegressor(max_features=1.0, random_state=1446671458),
#  DecisionTreeRegressor(max_features=1.0, random_state=259756310),
#  DecisionTreeRegressor(max_features=1.0, random_state=1073872487),
#  DecisionTreeRegressor(max_features=1.0, random_state=1958866459),
#  DecisionTreeRegressor(max_features=1.0, random_state=1965969696),
#  DecisionTreeRegressor(max_features=1.0, random_state=1001291664),
#  DecisionTreeRegressor(max_features=1.0, random_state=246671563),
#  DecisionTreeRegressor(max_features=1.0, random_state=1575770810),
#  DecisionTreeRegressor(max_features=1.0, random_state=1082117874),
#  DecisionTreeRegressor(max_features=1.0, random_state=1654286652),
#  DecisionTreeRegressor(max_features=1.0, random_state=473482857),
#  DecisionTreeRegressor(max_features=1.0, random_state=1315215346),
#  DecisionTreeRegressor(max_features=1.0, random_state=973399350),
#  DecisionTreeRegressor(max_features=1.0, random_state=295291872),
#  DecisionTreeRegressor(max_features=1.0, random_state=1331757433),
#  DecisionTreeRegressor(max_features=1.0, random_state=1741357254),
#  DecisionTreeRegressor(max_features=1.0, random_state=1399102624),
#  DecisionTreeRegressor(max_features=1.0, random_state=584224232),
#  DecisionTreeRegressor(max_features=1.0, random_state=1939892984),
#  DecisionTreeRegressor(max_features=1.0, random_state=86551696),
#  DecisionTreeRegressor(max_features=1.0, random_state=404323643),
#  DecisionTreeRegressor(max_features=1.0, random_state=774044134),
#  DecisionTreeRegressor(max_features=1.0, random_state=1663025244),
#  DecisionTreeRegressor(max_features=1.0, random_state=1401189247),
#  DecisionTreeRegressor(max_features=1.0, random_state=1038326071),
#  DecisionTreeRegressor(max_features=1.0, random_state=1243368536),
#  DecisionTreeRegressor(max_features=1.0, random_state=523695109),
#  DecisionTreeRegressor(max_features=1.0, random_state=2056125179),
#  DecisionTreeRegressor(max_features=1.0, random_state=1528446033),
#  DecisionTreeRegressor(max_features=1.0, random_state=1146094045),
#  DecisionTreeRegressor(max_features=1.0, random_state=287497679),
#  DecisionTreeRegressor(max_features=1.0, random_state=752255427)]

# %%
rfr.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': True,
#  'random_state': 45,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# # Aula 5 - Buscando a otimização da Floresta Aleatória

# %%
param_grid = {
    'max_depth': [None, 15, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [2, 5],
    'max_leaf_nodes': [400, 550]
}

# %%
rf = RandomForestRegressor(random_state=45)

grid_search_rfr = GridSearchCV(rf,
                               param_grid=param_grid,
                               scoring='neg_mean_squared_error',
                               cv=5,
                               n_jobs=-1)

grid_search_rfr.fit(X_treino, y_treino)

rfr_otimizado = grid_search_rfr.best_estimator_

print("Melhores parâmetros: ", grid_search_rfr.best_params_)
# Out:
# Melhores parâmetros:  {'max_depth': None, 'max_leaf_nodes': 550, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %%
print('Métricas conjunto de treino:')
print('R²:', r2_score(y_treino, rfr_otimizado.predict(X_treino)))
print('MAE:', mean_absolute_error(y_treino, rfr_otimizado.predict(X_treino)))
print('RMSE:', root_mean_squared_error(y_treino, rfr_otimizado.predict(X_treino)))

print('\n\nMétricas conjunto de teste:')
print('R²:', r2_score(y_teste, rfr_otimizado.predict(X_teste)))
print('MAE:', mean_absolute_error(y_teste, rfr_otimizado.predict(X_teste)))
print('RMSE:', root_mean_squared_error(y_teste, rfr_otimizado.predict(X_teste)))
# Out:
# Métricas conjunto de treino:
# R²: 0.966372224892234
# MAE: 223.1127138044924
# RMSE: 500.4728329544333
#
#
# Métricas conjunto de teste:
# R²: 0.8259394800792159
# MAE: 455.37640843101957
# RMSE: 1106.1635103057595

# %% [markdown]
# **VAMOS COMPARAR**
#
# ![](https://camo.githubusercontent.com/5077137cf2ce4bb93cc2e00ca5569dfd8759c12a286c89fe84047f401de8aad5/68747470733a2f2f6769746875622e636f6d2f4d69726c61612f72656772657373616f2d6172766f7265732f626c6f622f6d61696e2f696d6167656e732d70726f6a65746f2f696d6167656d2d352e706e673f7261773d74727565)

# %%
cv_estrategia = KFold(n_splits=3, shuffle=True, random_state=45)

resultados = cross_validate(rfr_otimizado,X,y,scoring='neg_mean_squared_error', cv= cv_estrategia,
                            return_train_score=True)

treino_rmse = np.sqrt(-resultados['train_score'])
teste_rmse = np.sqrt(-resultados['test_score'])

print("Média do RMSE no treino:", treino_rmse.mean())
print("Média do RMSE no teste:", teste_rmse.mean())
# Out:
# Média do RMSE no treino: 527.5049963671235
# Média do RMSE no teste: 1143.5396130830359

# %%
novos_dados = pd.read_csv(url_teste)

custos = rfr_otimizado.predict(novos_dados)

novos_dados['custo'] = custos
novos_dados
# Out:
#       reputacao_artista  altura  largura        peso  preco_escultura  \
# 0                  0.67  2.1336   1.2192   48.987936          36.3300
# 1                  0.61  1.8288   1.5240   43.998424          22.2075
# 2                  0.14  4.5720   2.4384  343.369144          32.9700
# 3                  0.63  3.0480   1.2192  758.859416          23.0475
# 4                  0.34  9.7536   1.8288  505.755080          34.9125
# ...                 ...     ...      ...         ...              ...
# 1429               0.00  2.1336   1.5240  736.179816          22.6275
# 1430               0.10  3.6576   1.8288  390.996304          27.7725
# 1431               0.20  1.2192   1.2192    9.071840          31.0800
# 1432               0.22  9.7536   2.4384  488.972176          27.7725
# 1433               0.47  7.3152   2.1336  242.671720          30.2925
#
#       preco_base_envio  diferenca_dias_entrega  data_agendada_dias  \
# 0              73.2900                       0                   2
# 1              71.5050                       2                   4
# 2             124.8975                       3                  14
# 3              93.6075                      -1                   3
# 4             119.7000                       4                   3
# ...                ...                     ...                 ...
# 1429          113.1375                      -3                  14
# 1430           80.6400                       0                   9
# 1431          105.5250                       4                   6
# 1432          112.8225                      -3                  21
# 1433          110.0400                      -3                  11
#
#       data_agendada_mes  data_agendada_ano  ...  material_Bronze  \
# 0                     5               2020  ...            False
# 1                     1               2022  ...            False
# 2                     9               2021  ...            False
# 3                    12               2021  ...            False
# 4                     2               2022  ...            False
# ...                 ...                ...  ...              ...
# 1429                 11               2021  ...            False
# 1430                 12               2019  ...             True
# 1431                  3               2022  ...            False
# 1432                  2               2023  ...            False
# 1433                  8               2021  ...            False
#
#       material_Latão  material_Madeira  material_Mármore  \
# 0              False             False             False
# 1              False             False             False
# 2              False             False             False
# 3              False             False              True
# 4              False             False             False
# ...              ...               ...               ...
# 1429           False             False              True
# 1430           False             False             False
# 1431           False             False             False
# 1432           False             False             False
# 1433           False             False             False
#
#       material_Não especificado  material_Pedra  transporte_Aéreo  \
# 0                         False           False             False
# 1                         False           False              True
# 2                         False           False             False
# 3                         False           False             False
# 4                         False           False              True
# ...                         ...             ...               ...
# 1429                      False           False              True
# 1430                      False           False             False
# 1431                      False           False             False
# 1432                      False           False             False
# 1433                      False           False              True
#
#       transporte_Não especificado  transporte_Rodoviário        custo
# 0                           False                   True  1160.319118
# 1                           False                  False  1117.674567
# 2                           False                   True  1009.792168
# 3                           False                   True  1557.430411
# 4                           False                  False  1440.866779
# ...                           ...                    ...          ...
# 1429                        False                  False   963.489644
# 1430                        False                   True   726.439325
# 1431                        False                   True   849.624140
# 1432                        False                  False  1077.269370
# 1433                        False                  False  1772.625567
#
# [1434 rows x 30 columns]

# %%
novos_dados.to_csv('Precos_entregas.csv', index=False)
